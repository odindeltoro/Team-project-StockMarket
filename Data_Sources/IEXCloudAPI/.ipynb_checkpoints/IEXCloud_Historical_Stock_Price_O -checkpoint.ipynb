# %% [markdown]
# # IEX Cloud API

# %% [markdown]
# **Data Coverage**
#
# 95,000+ securities, full U.S. market coverage, 20+ exchanges, 100+ currency pairs
#
# **Performance**
#
# 800M+ API calls per day, 28ms avg latency
#
# 5 year limit
#
# Filter by primary exchange index on paid subscription

# %% [markdown]
# Free account includes:
#
# * 50,000 core messages/mo
#
# * Unlimited Investors Exchange data
#
# * Unlimited Sandbox Testing
#
# * Limited access to Core Data:
#
# Intraday U.S. Stock Prices, Historical U.S. Stock Prices (5Y), Historical Intl Stock Prices (5Y), Earnings (last), Dividends (last), Splits (last), Reference Data, Mutual Funds, OTC (EOD), News, Crypto

# %%
# Import dependencies
import os
import requests
import json
import pandas as pd
from api_keys import apiKeySandbox

# %%
# URL for testing
base_url_sandbox = "https://sandbox.iexapis.com/" 
version = "stable/stock/"
symbol_ETF = "QQQ/"
endpoint = "chart/"
date_range = "max" 
token_sandbox = apiKeySandbox

# %%
# 5 Year ETF data
HTTP_request_sandbox_QQQ = f"{base_url_sandbox}{version}{symbol_ETF}{endpoint}{date_range}?token={token_sandbox}"
results_sandbox_QQQ = requests.get(HTTP_request_sandbox_QQQ).json()
results_sandbox_QQQ
# Out:
# [{'date': '2015-08-27',
#   'uClose': 109.08,
#   'uOpen': 108.93,
#   'uHigh': 110.7,
#   'uLow': 104.47,
#   'uVolume': 70749220,
#   'close': 107.96,
#   'open': 105.89,
#   'high': 106.25,
#   'low': 107.06,
#   'volume': 70036207,
#   'currency': '',
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Aug 27, 15',
#   'changeOverTime': 0},
#  {'date': '2015-08-28',
#   'uClose': 107.66,
#   'uOpen': 106.77,
#   'uHigh': 107,
#   'uLow': 107.65,
#   'uVolume': 50161028,
#   'close': 109.14,
#   'open': 110.3,
#   'high': 110,
#   'low': 106.73,
#   'volume': 52215129,
#   'currency': '',
#   'change': -0.02,
#   'changePercent': -0.0196,
#   'label': 'Aug 28, 15',
#   'changeOverTime': -0.000197},
#  {'date': '2015-08-31',
#   'uClose': 107.47,
#   'uOpen': 109.67,
#   'uHigh': 109.15,
#   'uLow': 108.54,
#   'uVolume': 40317283,
#   'close': 105.07,
#   'open': 106.32,
#   'high': 107.78,
#   'low': 107.81,
#   'volume': 41110041,
#   'currency': '',
#   'change': -1.37,
#   'changePercent': -1.2894,
#   'label': 'Aug 31, 15',
#   'changeOverTime': -0.01295},
#  {'date': '2015-09-01',
#   'uClose': 103.7,
#   'uOpen': 103.23,
#   'uHigh': 106.31,
#   'uLow': 103.67,
#   'uVolume': 75917290,
#   'close': 105.4,
#   'open': 103.01,
#   'high': 106.78,
#   'low': 105.62,
#   'volume': 74900132,
#   'currency': '',
#   'change': -3.4,
#   'changePercent': -3.248,
#   'label': 'Sep 1, 15',
#   'changeOverTime': -0.04384},
#  {'date': '2015-09-02',
#   'uClose': 105.1,
#   'uOpen': 107.82,
#   'uHigh': 108.02,
#   'uLow': 103.1,
#   'uVolume': 46089986,
#   'close': 105.2,
#   'open': 105.03,
#   'high': 105.22,
#   'low': 104.5,
#   'volume': 45376347,
#   'currency': '',
#   'change': 2.95,
#   'changePercent': 2.8237,
#   'label': 'Sep 2, 15',
#   'changeOverTime': -0.016995},
#  {'date': '2015-09-03',
#   'uClose': 106.49,
#   'uOpen': 108.33,
#   'uHigh': 106.49,
#   'uLow': 105.5,
#   'uVolume': 46793617,
#   'close': 104.53,
#   'open': 107.2,
#   'high': 108.72,
#   'low': 103.4,
#   'volume': 46369126,
#   'currency': '',
#   'change': -0.53,
#   'changePercent': -0.5135,
#   'label': 'Sep 3, 15',
#   'changeOverTime': -0.021674},
#  {'date': '2015-09-04',
#   'uClose': 106.69,
#   'uOpen': 102.31,
#   'uHigh': 107.25,
#   'uLow': 105.67,
#   'uVolume': 50075758,
#   'close': 105.27,
#   'open': 105.06,
#   'high': 105.97,
#   'low': 104.64,
#   'volume': 49886532,
#   'currency': '',
#   'change': -1.23,
#   'changePercent': -1.1967,
#   'label': 'Sep 4, 15',
#   'changeOverTime': -0.034192},
#  {'date': '2015-09-08',
#   'uClose': 105.85,
#   'uOpen': 107.29,
#   'uHigh': 105.81,
#   'uLow': 106.7,
#   'uVolume': 38903818,
#   'close': 108.79,
#   'open': 106.09,
#   'high': 106.4,
#   'low': 107.05,
#   'volume': 38741132,
#   'currency': '',
#   'change': 2.99,
#   'changePercent': 2.9138,
#   'label': 'Sep 8, 15',
#   'changeOverTime': -0.00595},
#  {'date': '2015-09-09',
#   'uClose': 107.13,
#   'uOpen': 111.07,
#   'uHigh': 109.34,
#   'uLow': 106.68,
#   'uVolume': 49209288,
#   'close': 108.7,
#   'open': 106.32,
#   'high': 107.88,
#   'low': 104.79,
#   'volume': 47638704,
#   'currency': '',
#   'change': -1.24,
#   'changePercent': -1.1658,
#   'label': 'Sep 9, 15',
#   'changeOverTime': -0.01738},
#  {'date': '2015-09-10',
#   'uClose': 106.01,
#   'uOpen': 106.15,
#   'uHigh': 109.85,
#   'uLow': 106.12,
#   'uVolume': 49797390,
#   'close': 106.76,
#   'open': 105.37,
#   'high': 109.83,
#   'low': 106.73,
#   'volume': 49384302,
#   'currency': '',
#   'change': 1.13,
#   'changePercent': 1.118,
#   'label': 'Sep 10, 15',
#   'changeOverTime': -0.006395},
#  {'date': '2015-09-11',
#   'uClose': 109.41,
#   'uOpen': 107.3,
#   'uHigh': 106.94,
#   'uLow': 107.41,
#   'uVolume': 30467587,
#   'close': 109.76,
#   'open': 109.69,
#   'high': 109.27,
#   'low': 107.31,
#   'volume': 30513446,
#   'currency': '',
#   'change': 0.6,
#   'changePercent': 0.5709,
#   'label': 'Sep 11, 15',
#   'changeOverTime': -0.000681},
#  {'date': '2015-09-14',
#   'uClose': 107.84,
#   'uOpen': 110.51,
#   'uHigh': 108.15,
#   'uLow': 106.03,
#   'uVolume': 20056394,
#   'close': 108.23,
#   'open': 110.42,
#   'high': 108.47,
#   'low': 108.13,
#   'volume': 20365842,
#   'currency': '',
#   'change': -0.34,
#   'changePercent': -0.3167,
#   'label': 'Sep 14, 15',
#   'changeOverTime': -0.003798},
#  {'date': '2015-09-15',
#   'uClose': 110.33,
#   'uOpen': 108.1,
#   'uHigh': 107.13,
#   'uLow': 108.8,
#   'uVolume': 31278856,
#   'close': 106.9,
#   'open': 105.9,
#   'high': 109.99,
#   'low': 105.88,
#   'volume': 30392201,
#   'currency': '',
#   'change': 1.28,
#   'changePercent': 1.2108,
#   'label': 'Sep 15, 15',
#   'changeOverTime': 0.008299},
#  {'date': '2015-09-16',
#   'uClose': 108.51,
#   'uOpen': 107.09,
#   'uHigh': 109.85,
#   'uLow': 107.38,
#   'uVolume': 32643850,
#   'close': 107.85,
#   'open': 109.38,
#   'high': 109.99,
#   'low': 110.04,
#   'volume': 32027809,
#   'currency': '',
#   'change': 0.6,
#   'changePercent': 0.5772,
#   'label': 'Sep 16, 15',
#   'changeOverTime': 0.014407},
#  {'date': '2015-09-17',
#   'uClose': 108.41,
#   'uOpen': 110.64,
#   'uHigh': 112.11,
#   'uLow': 107.93,
#   'uVolume': 58066645,
#   'close': 108.08,
#   'open': 108.61,
#   'high': 112.07,
#   'low': 108.75,
#   'volume': 57256393,
#   'currency': '',
#   'change': 0.04,
#   'changePercent': 0.0393,
#   'label': 'Sep 17, 15',
#   'changeOverTime': 0.014657},
#  {'date': '2015-09-18',
#   'uClose': 108.4,
#   'uOpen': 105.51,
#   'uHigh': 111.9,
#   'uLow': 108.4,
#   'uVolume': 50336856,
#   'close': 105.91,
#   'open': 108.98,
#   'high': 107.2,
#   'low': 110.41,
#   'volume': 50338360,
#   'currency': '',
#   'change': -1.86,
#   'changePercent': -1.7273,
#   'label': 'Sep 18, 15',
#   'changeOverTime': -0.002752},
#  {'date': '2015-09-21',
#   'uClose': 110.88,
#   'uOpen': 109.31,
#   'uHigh': 111.87,
#   'uLow': 109.61,
#   'uVolume': 36405379,
#   'close': 108.19,
#   'open': 108.81,
#   'high': 110.41,
#   'low': 104.78,
#   'volume': 35923702,
#   'currency': '',
#   'change': 0.34,
#   'changePercent': 0.3185,
#   'label': 'Sep 21, 15',
#   'changeOverTime': 0.000385},
#  {'date': '2015-09-22',
#   'uClose': 105.3,
#   'uOpen': 106.71,
#   'uHigh': 104.76,
#   'uLow': 106.77,
#   'uVolume': 49144316,
#   'close': 107.6,
#   'open': 107.07,
#   'high': 106.69,
#   'low': 108.13,
#   'volume': 48539932,
#   'currency': '',
#   'change': -1.62,
#   'changePercent': -1.5624,
#   'label': 'Sep 22, 15',
#   'changeOverTime': -0.014996},
#  {'date': '2015-09-23',
#   'uClose': 108.14,
#   'uOpen': 104.63,
#   'uHigh': 106.63,
#   'uLow': 108.16,
#   'uVolume': 21946515,
#   'close': 104.65,
#   'open': 108.88,
#   'high': 107.77,
#   'low': 107.58,
#   'volume': 22438701,
#   'currency': '',
#   'change': 0.08,
#   'changePercent': 0.0795,
#   'label': 'Sep 23, 15',
#   'changeOverTime': -0.014094},
#  {'date': '2015-09-24',
#   'uClose': 108.2,
#   'uOpen': 108.12,
#   'uHigh': 105.24,
#   'uLow': 106.45,
#   'uVolume': 40198187,
#   'close': 105.3,
#   'open': 104.96,
#   'high': 107.1,
#   'low': 102.44,
#   'volume': 38938382,
#   'currency': '',
#   'change': -0.39,
#   'changePercent': -0.3661,
#   'label': 'Sep 24, 15',
#   'changeOverTime': -0.01767},
#  {'date': '2015-09-25',
#   'uClose': 107.72,
#   'uOpen': 109.83,
#   'uHigh': 107.15,
#   'uLow': 104.05,
#   'uVolume': 45316793,
#   'close': 105.13,
#   'open': 107.33,
#   'high': 105.31,
#   'low': 107.2,
#   'volume': 46675402,
#   'currency': '',
#   'change': -0.88,
#   'changePercent': -0.8858,
#   'label': 'Sep 25, 15',
#   'changeOverTime': -0.026128},
#  {'date': '2015-09-28',
#   'uClose': 104.99,
#   'uOpen': 104.42,
#   'uHigh': 105.94,
#   'uLow': 103.53,
#   'uVolume': 44500090,
#   'close': 103.26,
#   'open': 104.16,
#   'high': 104.42,
#   'low': 99.95,
#   'volume': 44329812,
#   'currency': '',
#   'change': -3,
#   'changePercent': -2.8989,
#   'label': 'Sep 28, 15',
#   'changeOverTime': -0.05373},
#  {'date': '2015-09-29',
#   'uClose': 101.23,
#   'uOpen': 101.79,
#   'uHigh': 102.33,
#   'uLow': 101.73,
#   'uVolume': 51376616,
#   'close': 103.61,
#   'open': 101.36,
#   'high': 102.8,
#   'low': 103.66,
#   'volume': 50340640,
#   'currency': '',
#   'change': -0.52,
#   'changePercent': -0.5263,
#   'label': 'Sep 29, 15',
#   'changeOverTime': -0.060288},
#  {'date': '2015-09-30',
#   'uClose': 104.1,
#   'uOpen': 105.66,
#   'uHigh': 106.55,
#   'uLow': 103.5,
#   'uVolume': 42571167,
#   'close': 103.65,
#   'open': 104.11,
#   'high': 101.99,
#   'low': 104.5,
#   'volume': 41423459,
#   'currency': '',
#   'change': 2.4,
#   'changePercent': 2.338,
#   'label': 'Sep 30, 15',
#   'changeOverTime': -0.038431},
#  {'date': '2015-10-01',
#   'uClose': 106.05,
#   'uOpen': 105.58,
#   'uHigh': 106.02,
#   'uLow': 101.5,
#   'uVolume': 39721106,
#   'close': 105.67,
#   'open': 103.93,
#   'high': 104.84,
#   'low': 100.83,
#   'volume': 40688473,
#   'currency': '',
#   'change': 0.47,
#   'changePercent': 0.465,
#   'label': 'Oct 1, 15',
#   'changeOverTime': -0.033941},
#  {'date': '2015-10-02',
#   'uClose': 105.1,
#   'uOpen': 102.5,
#   'uHigh': 104.04,
#   'uLow': 104.87,
#   'uVolume': 60591567,
#   'close': 105.7,
#   'open': 105.6,
#   'high': 104.74,
#   'low': 101.48,
#   'volume': 59861922,
#   'currency': '',
#   'change': 1.84,
#   'changePercent': 1.757,
#   'label': 'Oct 2, 15',
#   'changeOverTime': -0.01549},
#  {'date': '2015-10-05',
#   'uClose': 107.1,
#   'uOpen': 109.12,
#   'uHigh': 109.47,
#   'uLow': 109.53,
#   'uVolume': 32950103,
#   'close': 108,
#   'open': 105.17,
#   'high': 109.24,
#   'low': 108.3,
#   'volume': 34116634,
#   'currency': '',
#   'change': 1.55,
#   'changePercent': 1.4454,
#   'label': 'Oct 5, 15',
#   'changeOverTime': -0.001325},
#  {'date': '2015-10-06',
#   'uClose': 108,
#   'uOpen': 108.12,
#   'uHigh': 108.1,
#   'uLow': 105.16,
#   'uVolume': 34671120,
#   'close': 107,
#   'open': 105.27,
#   'high': 110.7,
#   'low': 107.97,
#   'volume': 33485867,
#   'currency': '',
#   'change': -0.5,
#   'changePercent': -0.4823,
#   'label': 'Oct 6, 15',
#   'changeOverTime': -0.006271},
#  {'date': '2015-10-07',
#   'uClose': 106.58,
#   'uOpen': 107.75,
#   'uHigh': 109.12,
#   'uLow': 106.85,
#   'uVolume': 37831754,
#   'close': 108.52,
#   'open': 108.33,
#   'high': 108.9,
#   'low': 109.3,
#   'volume': 39002911,
#   'currency': '',
#   'change': 0.65,
#   'changePercent': 0.6,
#   'label': 'Oct 7, 15',
#   'changeOverTime': -9.8e-05},
#  {'date': '2015-10-08',
#   'uClose': 109.39,
#   'uOpen': 109.03,
#   'uHigh': 107.52,
#   'uLow': 109.16,
#   'uVolume': 52432530,
#   'close': 109.63,
#   'open': 105.65,
#   'high': 107.94,
#   'low': 107.43,
#   'volume': 50678772,
#   'currency': '',
#   'change': 0.44,
#   'changePercent': 0.4012,
#   'label': 'Oct 8, 15',
#   'changeOverTime': 0.004034},
#  {'date': '2015-10-09',
#   'uClose': 111.3,
#   'uOpen': 108.1,
#   'uHigh': 110.79,
#   'uLow': 106.29,
#   'uVolume': 23988184,
#   'close': 111.68,
#   'open': 110.5,
#   'high': 108.74,
#   'low': 106.77,
#   'volume': 24677542,
#   'currency': '',
#   'change': 0.48,
#   'changePercent': 0.464,
#   'label': 'Oct 9, 15',
#   'changeOverTime': 0.008486},
#  {'date': '2015-10-12',
#   'uClose': 110,
#   'uOpen': 107.54,
#   'uHigh': 111.58,
#   'uLow': 107.5,
#   'uVolume': 16822063,
#   'close': 108.24,
#   'open': 110.79,
#   'high': 107.95,
#   'low': 111.36,
#   'volume': 16185979,
#   'currency': '',
#   'change': 0.27,
#   'changePercent': 0.2443,
#   'label': 'Oct 12, 15',
#   'changeOverTime': 0.011283},
#  {'date': '2015-10-13',
#   'uClose': 111.2,
#   'uOpen': 111.29,
#   'uHigh': 111.31,
#   'uLow': 109,
#   'uVolume': 27933331,
#   'close': 108.1,
#   'open': 107.81,
#   'high': 107.46,
#   'low': 108,
#   'volume': 28188576,
#   'currency': '',
#   'change': -0.7,
#   'changePercent': -0.6744,
#   'label': 'Oct 13, 15',
#   'changeOverTime': 0.004446},
#  {'date': '2015-10-14',
#   'uClose': 105.97,
#   'uOpen': 111.1,
#   'uHigh': 106.64,
#   'uLow': 106.35,
#   'uVolume': 32103328,
#   'close': 108.73,
#   'open': 109.8,
#   'high': 109.42,
#   'low': 110.13,
#   'volume': 31768789,
#   'currency': '',
#   'change': -0.17,
#   'changePercent': -0.1644,
#   'label': 'Oct 14, 15',
#   'changeOverTime': 0.002792},
#  {'date': '2015-10-15',
#   'uClose': 111,
#   'uOpen': 108.11,
#   'uHigh': 112.59,
#   'uLow': 110.41,
#   'uVolume': 39649367,
#   'close': 112.28,
#   'open': 108.33,
#   'high': 109.03,
#   'low': 107.46,
#   'volume': 40070465,
#   'currency': '',
#   'change': 1.82,
#   'changePercent': 1.7163,
#   'label': 'Oct 15, 15',
#   'changeOverTime': 0.019746},
#  {'date': '2015-10-16',
#   'uClose': 113.15,
#   'uOpen': 110.5,
#   'uHigh': 113.11,
#   'uLow': 109.42,
#   'uVolume': 27308251,
#   'close': 111.92,
#   'open': 111.4,
#   'high': 111.36,
#   'low': 110.86,
#   'volume': 27174267,
#   'currency': '',
#   'change': 0.47,
#   'changePercent': 0.4289,
#   'label': 'Oct 16, 15',
#   'changeOverTime': 0.023808},
#  {'date': '2015-10-19',
#   'uClose': 110.69,
#   'uOpen': 111.08,
#   'uHigh': 112.61,
#   'uLow': 107.77,
#   'uVolume': 23911337,
#   'close': 110.66,
#   'open': 110.52,
#   'high': 110.11,
#   'low': 109.35,
#   'volume': 24191246,
#   'currency': '',
#   'change': 0.65,
#   'changePercent': 0.584,
#   'label': 'Oct 19, 15',
#   'changeOverTime': 0.029489},
#  {'date': '2015-10-20',
#   'uClose': 108.29,
#   'uOpen': 109.12,
#   'uHigh': 113.36,
#   'uLow': 110.37,
#   'uVolume': 23700858,
#   'close': 112,
#   'open': 108.94,
#   'high': 111.48,
#   'low': 110.33,
#   'volume': 24443683,
#   'currency': '',
#   'change': -0.58,
#   'changePercent': -0.53,
#   'label': 'Oct 20, 15',
#   'changeOverTime': 0.02504},
#  {'date': '2015-10-21',
#   'uClose': 109.86,
#   'uOpen': 111.1,
#   'uHigh': 113.74,
#   'uLow': 112.1,
#   'uVolume': 30453090,
#   'close': 112.01,
#   'open': 111.48,
#   'high': 109,
#   'low': 110.21,
#   'volume': 31532708,
#   'currency': '',
#   'change': -0.66,
#   'changePercent': -0.6156,
#   'label': 'Oct 21, 15',
#   'changeOverTime': 0.018173},
#  {'date': '2015-10-22',
#   'uClose': 111.2,
#   'uOpen': 110.82,
#   'uHigh': 110.6,
#   'uLow': 112.26,
#   'uVolume': 43552124,
#   'close': 110.67,
#   'open': 111.12,
#   'high': 113.9,
#   'low': 110.86,
#   'volume': 43574692,
#   'currency': '',
#   'change': 2.28,
#   'changePercent': 2.0762,
#   'label': 'Oct 22, 15',
#   'changeOverTime': 0.039566},
#  {'date': '2015-10-23',
#   'uClose': 117.42,
#   'uOpen': 112.76,
#   'uHigh': 118.33,
#   'uLow': 116.56,
#   'uVolume': 53426738,
#   'close': 118.19,
#   'open': 114.88,
#   'high': 118.09,
#   'low': 115.74,
#   'volume': 53230072,
#   'currency': '',
#   'change': 3.12,
#   'changePercent': 2.8234,
#   'label': 'Oct 23, 15',
#   'changeOverTime': 0.069362},
#  {'date': '2015-10-26',
#   'uClose': 115.69,
#   'uOpen': 116.6,
#   'uHigh': 114.67,
#   'uLow': 112.98,
#   'uVolume': 26359690,
#   'close': 115.54,
#   'open': 116.5,
#   'high': 113.7,
#   'low': 116.25,
#   'volume': 26990732,
#   'currency': '',
#   'change': 0.07,
#   'changePercent': 0.0637,
#   'label': 'Oct 26, 15',
#   'changeOverTime': 0.071604},
#  {'date': '2015-10-27',
#   'uClose': 114.56,
#   'uOpen': 116.8,
#   'uHigh': 115.54,
#   'uLow': 112.96,
#   'uVolume': 32607147,
#   'close': 113.66,
#   'open': 115.93,
#   'high': 113.8,
#   'low': 116.91,
#   'volume': 32588271,
#   'currency': '',
#   'change': 0.24,
#   'changePercent': 0.2048,
#   'label': 'Oct 27, 15',
#   'changeOverTime': 0.072302},
#  {'date': '2015-10-28',
#   'uClose': 118.17,
#   'uOpen': 117.41,
#   'uHigh': 115,
#   'uLow': 113.61,
#   'uVolume': 42510161,
#   'close': 119.57,
#   'open': 117.77,
#   'high': 115.65,
#   'low': 113.63,
#   'volume': 42803073,
#   'currency': '',
#   'change': 0.94,
#   'changePercent': 0.8557,
#   'label': 'Oct 28, 15',
#   'changeOverTime': 0.079997},
#  {'date': '2015-10-29',
#   'uClose': 114.8,
#   'uOpen': 114.9,
#   'uHigh': 115.46,
#   'uLow': 117.74,
#   'uVolume': 25373646,
#   'close': 117.86,
#   'open': 113.7,
#   'high': 116.73,
#   'low': 117.93,
#   'volume': 25796608,
#   'currency': '',
#   'change': -0.19,
#   'changePercent': -0.1619,
#   'label': 'Oct 29, 15',
#   'changeOverTime': 0.078562},
#  {'date': '2015-10-30',
#   'uClose': 117.5,
#   'uOpen': 117.2,
#   'uHigh': 119.75,
#   'uLow': 117.6,
#   'uVolume': 28110148,
#   'close': 116.99,
#   'open': 117.1,
#   'high': 114.86,
#   'low': 115,
#   'volume': 27442864,
#   'currency': '',
#   'change': -0.54,
#   'changePercent': -0.452,
#   'label': 'Oct 30, 15',
#   'changeOverTime': 0.074043},
#  {'date': '2015-11-02',
#   'uClose': 118.12,
#   'uOpen': 115.99,
#   'uHigh': 118.82,
#   'uLow': 115.4,
#   'uVolume': 22669072,
#   'close': 119.4,
#   'open': 117.83,
#   'high': 117.31,
#   'low': 114.11,
#   'volume': 22432919,
#   'currency': '',
#   'change': 1.32,
#   'changePercent': 1.1526,
#   'label': 'Nov 2, 15',
#   'changeOverTime': 0.085107},
#  {'date': '2015-11-03',
#   'uClose': 119.74,
#   'uOpen': 119.73,
#   'uHigh': 120.18,
#   'uLow': 115.22,
#   'uVolume': 21059058,
#   'close': 115.65,
#   'open': 115.1,
#   'high': 115.57,
#   'low': 118.85,
#   'volume': 21120887,
#   'currency': '',
#   'change': 0.4,
#   'changePercent': 0.363,
#   'label': 'Nov 3, 15',
#   'changeOverTime': 0.08913},
#  {'date': '2015-11-04',
#   'uClose': 119.37,
#   'uOpen': 120.97,
#   'uHigh': 117.7,
#   'uLow': 118.31,
#   'uVolume': 28695551,
#   'close': 116.07,
#   'open': 119.3,
#   'high': 117.72,
#   'low': 119.71,
#   'volume': 29274309,
#   'currency': '',
#   'change': 0.01,
#   'changePercent': 0.0089,
#   'label': 'Nov 4, 15',
#   'changeOverTime': 0.09296},
#  {'date': '2015-11-05',
#   'uClose': 118.93,
#   'uOpen': 120.7,
#   'uHigh': 117.7,
#   'uLow': 119.62,
#   'uVolume': 25267328,
#   'close': 120.34,
#   'open': 120.85,
#   'high': 115.53,
#   'low': 117.9,
#   'volume': 25115669,
#   'currency': '',
#   'change': -0.32,
#   'changePercent': -0.2766,
#   'label': 'Nov 5, 15',
#   'changeOverTime': 0.087414},
#  {'date': '2015-11-06',
#   'uClose': 117.19,
#   'uOpen': 117.04,
#   'uHigh': 119.27,
#   'uLow': 119.28,
#   'uVolume': 30061683,
#   'close': 120.13,
#   'open': 118.83,
#   'high': 116.19,
#   'low': 115.41,
#   'volume': 31325208,
#   'currency': '',
#   'change': 0.08,
#   'changePercent': 0.0721,
#   'label': 'Nov 6, 15',
#   'changeOverTime': 0.087749},
#  {'date': '2015-11-09',
#   'uClose': 113.61,
#   'uOpen': 118.79,
#   'uHigh': 115.86,
#   'uLow': 118.45,
#   'uVolume': 35011672,
#   'close': 117.15,
#   'open': 116.73,
#   'high': 114.76,
#   'low': 113.88,
#   'volume': 34965043,
#   'currency': '',
#   'change': -1.27,
#   'changePercent': -1.107,
#   'label': 'Nov 9, 15',
#   'changeOverTime': 0.07544},
#  {'date': '2015-11-10',
#   'uClose': 118.52,
#   'uOpen': 114.62,
#   'uHigh': 113.79,
#   'uLow': 116.74,
#   'uVolume': 36700074,
#   'close': 116.82,
#   'open': 115.3,
#   'high': 114.39,
#   'low': 114.64,
#   'volume': 36376585,
#   'currency': '',
#   'change': -0.3,
#   'changePercent': -0.2646,
#   'label': 'Nov 10, 15',
#   'changeOverTime': 0.073425},
#  {'date': '2015-11-11',
#   'uClose': 118.12,
#   'uOpen': 114.7,
#   'uHigh': 116.51,
#   'uLow': 116.97,
#   'uVolume': 23654391,
#   'close': 115.51,
#   'open': 118.09,
#   'high': 118.91,
#   'low': 114.82,
#   'volume': 22953936,
#   'currency': '',
#   'change': -0.14,
#   'changePercent': -0.1281,
#   'label': 'Nov 11, 15',
#   'changeOverTime': 0.07154},
#  {'date': '2015-11-12',
#   'uClose': 113.73,
#   'uOpen': 114.41,
#   'uHigh': 114.46,
#   'uLow': 115.18,
#   'uVolume': 32740196,
#   'close': 117.09,
#   'open': 113.83,
#   'high': 115.1,
#   'low': 113.13,
#   'volume': 31711791,
#   'currency': '',
#   'change': -1.1,
#   'changePercent': -0.9744,
#   'label': 'Nov 12, 15',
#   'changeOverTime': 0.062485},
#  {'date': '2015-11-13',
#   'uClose': 114.03,
#   'uOpen': 113.96,
#   'uHigh': 113.02,
#   'uLow': 110.54,
#   'uVolume': 53643741,
#   'close': 112.87,
#   'open': 113.46,
#   'high': 115.43,
#   'low': 109.88,
#   'volume': 52960860,
#   'currency': '',
#   'change': -2.2,
#   'changePercent': -2.0213,
#   'label': 'Nov 13, 15',
#   'changeOverTime': 0.041698},
#  {'date': '2015-11-16',
#   'uClose': 115.96,
#   'uOpen': 111.62,
#   'uHigh': 112.62,
#   'uLow': 111.67,
#   'uVolume': 34095314,
#   'close': 114.36,
#   'open': 112.45,
#   'high': 111.96,
#   'low': 110.47,
#   'volume': 35470904,
#   'currency': '',
#   'change': 1.66,
#   'changePercent': 1.4866,
#   'label': 'Nov 16, 15',
#   'changeOverTime': 0.056146},
#  {'date': '2015-11-17',
#   'uClose': 114.03,
#   'uOpen': 115.26,
#   'uHigh': 117.21,
#   'uLow': 114.93,
#   'uVolume': 31284849,
#   'close': 114.45,
#   'open': 117.04,
#   'high': 114.36,
#   'low': 112.4,
#   'volume': 32045089,
#   'currency': '',
#   'change': 0.07,
#   'changePercent': 0.0649,
#   'label': 'Nov 17, 15',
#   'changeOverTime': 0.056605},
#  {'date': '2015-11-18',
#   'uClose': 116.8,
#   'uOpen': 116.95,
#   'uHigh': 115.19,
#   'uLow': 115.83,
#   'uVolume': 33605658,
#   'close': 118.7,
#   'open': 115.75,
#   'high': 118.55,
#   'low': 114.9,
#   'volume': 33917429,
#   'currency': '',
#   'change': 2.22,
#   'changePercent': 1.9663,
#   'label': 'Nov 18, 15',
#   'changeOverTime': 0.078442},
#  {'date': '2015-11-19',
#   'uClose': 115.62,
#   'uOpen': 117.76,
#   'uHigh': 118.86,
#   'uLow': 117.92,
#   'uVolume': 27475899,
#   'close': 115.75,
#   'open': 118.06,
#   'high': 115.56,
#   'low': 116.73,
#   'volume': 26578794,
#   'currency': '',
#   'change': 0.08,
#   'changePercent': 0.0709,
#   'label': 'Nov 19, 15',
#   'changeOverTime': 0.079322},
#  {'date': '2015-11-20',
#   'uClose': 120.08,
#   'uOpen': 118.19,
#   'uHigh': 116.7,
#   'uLow': 117.09,
#   'uVolume': 23022660,
#   'close': 117.17,
#   'open': 116.9,
#   'high': 120.14,
#   'low': 119.39,
#   'volume': 23084379,
#   'currency': '',
#   'change': 0.8,
#   'changePercent': 0.6965,
#   'label': 'Nov 20, 15',
#   'changeOverTime': 0.0867},
#  {'date': '2015-11-23',
#   'uClose': 114.94,
#   'uOpen': 117.49,
#   'uHigh': 116.62,
#   'uLow': 118.13,
#   'uVolume': 21024761,
#   'close': 115.39,
#   'open': 116.35,
#   'high': 115.83,
#   'low': 118.99,
#   'volume': 21678155,
#   'currency': '',
#   'change': -0.34,
#   'changePercent': -0.2907,
#   'label': 'Nov 23, 15',
#   'changeOverTime': 0.083414},
#  {'date': '2015-11-24',
#   'uClose': 116.83,
#   'uOpen': 114.36,
#   'uHigh': 117.65,
#   'uLow': 115.95,
#   'uVolume': 26612177,
#   'close': 117.71,
#   'open': 118.07,
#   'high': 117.71,
#   'low': 115.39,
#   'volume': 26645966,
#   'currency': '',
#   'change': -0.1,
#   'changePercent': -0.0906,
#   'label': 'Nov 24, 15',
#   'changeOverTime': 0.08343},
#  {'date': '2015-11-25',
#   'uClose': 117.03,
#   'uOpen': 115.05,
#   'uHigh': 115.46,
#   'uLow': 114.22,
#   'uVolume': 14166870,
#   'close': 116.79,
#   'open': 116.56,
#   'high': 115.4,
#   'low': 117.04,
#   'volume': 14280161,
#   'currency': '',
#   'change': 0.1,
#   'changePercent': 0.089,
#   'label': 'Nov 25, 15',
#   'changeOverTime': 0.082894},
#  {'date': '2015-11-27',
#   'uClose': 119.26,
#   'uOpen': 117.3,
#   'uHigh': 116.09,
#   'uLow': 116.32,
#   'uVolume': 8974616,
#   'close': 115.68,
#   'open': 119.35,
#   'high': 119.4,
#   'low': 114.55,
#   'volume': 8980728,
#   'currency': '',
#   'change': 0.16,
#   'changePercent': 0.1405,
#   'label': 'Nov 27, 15',
#   'changeOverTime': 0.082082},
#  {'date': '2015-11-30',
#   'uClose': 118.46,
#   'uOpen': 119.4,
#   'uHigh': 119.68,
#   'uLow': 117.48,
#   'uVolume': 26247979,
#   'close': 115.89,
#   'open': 117.8,
#   'high': 117.47,
#   'low': 116.93,
#   'volume': 25912837,
#   'currency': '',
#   'change': -0.3,
#   'changePercent': -0.2584,
#   'label': 'Nov 30, 15',
#   'changeOverTime': 0.082545},
#  {'date': '2015-12-01',
#   'uClose': 118.09,
#   'uOpen': 116.3,
#   'uHigh': 115.47,
#   'uLow': 115.2,
#   'uVolume': 29051354,
#   'close': 118.06,
#   'open': 116.74,
#   'high': 117.69,
#   'low': 118.02,
#   'volume': 29760521,
#   'currency': '',
#   'change': 1.18,
#   'changePercent': 1.0039,
#   'label': 'Dec 1, 15',
#   'changeOverTime': 0.092654},
#  {'date': '2015-12-02',
#   'uClose': 114.83,
#   'uOpen': 119.31,
#   'uHigh': 119.08,
#   'uLow': 116.12,
#   'uVolume': 22648551,
#   'close': 120.03,
#   'open': 120.85,
#   'high': 118.43,
#   'low': 118.14,
#   'volume': 23175098,
#   'currency': '',
#   'change': -0.73,
#   'changePercent': -0.6385,
#   'label': 'Dec 2, 15',
#   'changeOverTime': 0.087338},
#  {'date': '2015-12-03',
#   'uClose': 114.09,
#   'uOpen': 114.91,
#   'uHigh': 116.86,
#   'uLow': 112.88,
#   'uVolume': 43874741,
#   'close': 117.83,
#   'open': 119.84,
#   'high': 117.59,
#   'low': 117.37,
#   'volume': 43680734,
#   'currency': '',
#   'change': -1.94,
#   'changePercent': -1.7574,
#   'label': 'Dec 3, 15',
#   'changeOverTime': 0.068269},
#  {'date': '2015-12-04',
#   'uClose': 119.23,
#   'uOpen': 116.36,
#   'uHigh': 117.23,
#   'uLow': 116.3,
#   'uVolume': 41747208,
#   'close': 118.7,
#   'open': 113.79,
#   'high': 120.69,
#   'low': 114.04,
#   'volume': 41675709,
#   'currency': '',
#   'change': 2.7,
#   'changePercent': 2.3932,
#   'label': 'Dec 4, 15',
#   'changeOverTime': 0.093389},
#  {'date': '2015-12-07',
#   'uClose': 118.35,
#   'uOpen': 117.08,
#   'uHigh': 119.46,
#   'uLow': 117.26,
#   'uVolume': 27067180,
#   'close': 117.35,
#   'open': 119.86,
#   'high': 117.43,
#   'low': 116.57,
#   'volume': 25909642,
#   'currency': '',
#   'change': -0.53,
#   'changePercent': -0.46,
#   'label': 'Dec 7, 15',
#   'changeOverTime': 0.088918},
#  {'date': '2015-12-08',
#   'uClose': 117.57,
#   'uOpen': 117.34,
#   'uHigh': 119,
#   'uLow': 113.99,
#   'uVolume': 30918693,
#   'close': 115.43,
#   'open': 115.94,
#   'high': 117,
#   'low': 116.95,
#   'volume': 31124768,
#   'currency': '',
#   'change': 0.01,
#   'changePercent': 0.0091,
#   'label': 'Dec 8, 15',
#   'changeOverTime': 0.0854},
#  {'date': '2015-12-09',
#   'uClose': 113.24,
#   'uOpen': 116.97,
#   'uHigh': 116.01,
#   'uLow': 112.9,
#   'uVolume': 49984333,
#   'close': 116.05,
#   'open': 115.39,
#   'high': 118.25,
#   'low': 113.3,
#   'volume': 49199425,
#   'currency': '',
#   'change': -1.76,
#   'changePercent': -1.5203,
#   'label': 'Dec 9, 15',
#   'changeOverTime': 0.071851},
#  {'date': '2015-12-10',
#   'uClose': 113.9,
#   'uOpen': 117.79,
#   'uHigh': 118.37,
#   'uLow': 114.93,
#   'uVolume': 31348029,
#   'close': 118.2,
#   'open': 113.83,
#   'high': 118.29,
#   'low': 115.24,
#   'volume': 30799713,
#   'currency': '',
#   'change': 0.53,
#   'changePercent': 0.4719,
#   'label': 'Dec 10, 15',
#   'changeOverTime': 0.075383},
#  {'date': '2015-12-11',
#   'uClose': 111.49,
#   'uOpen': 114,
#   'uHigh': 112.97,
#   'uLow': 115.61,
#   'uVolume': 57980727,
#   'close': 111.51,
#   'open': 112.31,
#   'high': 115.46,
#   'low': 113.99,
#   'volume': 57871940,
#   'currency': '',
#   'change': -2.73,
#   'changePercent': -2.3912,
#   'label': 'Dec 11, 15',
#   'changeOverTime': 0.04988},
#  {'date': '2015-12-14',
#   'uClose': 116.03,
#   'uOpen': 115.47,
#   'uHigh': 113.48,
#   'uLow': 111.13,
#   'uVolume': 53921308,
#   'close': 112.91,
#   'open': 114.97,
#   'high': 115.43,
#   'low': 109.75,
#   'volume': 55103123,
#   'currency': '',
#   'change': 0.87,
#   'changePercent': 0.7699,
#   'label': 'Dec 14, 15',
#   'changeOverTime': 0.056846},
#  {'date': '2015-12-15',
#   'uClose': 112.98,
#   'uOpen': 114.2,
#   'uHigh': 118.68,
#   'uLow': 116.62,
#   'uVolume': 48921221,
#   'close': 113.09,
#   'open': 116.2,
#   'high': 114.89,
#   'low': 115.58,
#   'volume': 50040230,
#   'currency': '',
#   'change': 0.69,
#   'changePercent': 0.6363,
#   'label': 'Dec 15, 15',
#   'changeOverTime': 0.064205},
#  {'date': '2015-12-16',
#   'uClose': 117.12,
#   'uOpen': 116.69,
#   'uHigh': 114.25,
#   'uLow': 113.85,
#   'uVolume': 45418286,
#   'close': 117.36,
#   'open': 113.9,
#   'high': 117.83,
#   'low': 113.86,
#   'volume': 45183913,
#   'currency': '',
#   'change': 1.73,
#   'changePercent': 1.559,
#   'label': 'Dec 16, 15',
#   'changeOverTime': 0.081926},
#  {'date': '2015-12-17',
#   'uClose': 114.36,
#   'uOpen': 119.71,
#   'uHigh': 119.48,
#   'uLow': 113.2,
#   'uVolume': 46815427,
#   'close': 115.46,
#   'open': 118.77,
#   'high': 118.66,
#   'low': 114.6,
#   'volume': 46980137,
#   'currency': '',
#   'change': -1.72,
#   'changePercent': -1.4938,
#   'label': 'Dec 17, 15',
#   'changeOverTime': 0.064803},
#  {'date': '2015-12-18',
#   'uClose': 110.9,
#   'uOpen': 111.69,
#   'uHigh': 115.31,
#   'uLow': 114.18,
#   'uVolume': 55655186,
#   'close': 110.31,
#   'open': 112.24,
#   'high': 115.49,
#   'low': 113.68,
#   'volume': 55421077,
#   'currency': '',
#   'change': -2.5,
#   'changePercent': -2.2237,
#   'label': 'Dec 18, 15',
#   'changeOverTime': 0.040648},
#  {'date': '2015-12-21',
#   'uClose': 113.77,
#   'uOpen': 115.72,
#   'uHigh': 114.01,
#   'uLow': 110.33,
#   'uVolume': 27462475,
#   'close': 112.85,
#   'open': 113.02,
#   'high': 111.26,
#   'low': 113.38,
#   'volume': 27193537,
#   'currency': '',
#   'change': 1.24,
#   'changePercent': 1.1266,
#   'label': 'Dec 21, 15',
#   'changeOverTime': 0.053271},
#  {'date': '2015-12-22',
#   'uClose': 115.66,
#   'uOpen': 114.09,
#   'uHigh': 113.7,
#   'uLow': 112.96,
#   'uVolume': 27272215,
#   'close': 116.29,
#   'open': 112.7,
#   'high': 113.27,
#   'low': 115.81,
#   'volume': 27700982,
#   'currency': '',
#   'change': 0.74,
#   'changePercent': 0.6829,
#   'label': 'Dec 22, 15',
#   'changeOverTime': 0.058882},
#  {'date': '2015-12-23',
#   'uClose': 115.63,
#   'uOpen': 115.43,
#   'uHigh': 113.03,
#   'uLow': 116.57,
#   'uVolume': 26582866,
#   'close': 112.69,
#   'open': 114.74,
#   'high': 117.65,
#   'low': 112.5,
#   'volume': 26487754,
#   'currency': '',
#   'change': 0.83,
#   'changePercent': 0.7497,
#   'label': 'Dec 23, 15',
#   'changeOverTime': 0.06816},
#  {'date': '2015-12-24',
#   'uClose': 115.03,
#   'uOpen': 115.1,
#   'uHigh': 116.8,
#   'uLow': 115.61,
#   'uVolume': 11602878,
#   'close': 115.19,
#   'open': 113.87,
#   'high': 116.4,
#   'low': 114.62,
#   'volume': 11886044,
#   'currency': '',
#   'change': -0.02,
#   'changePercent': -0.0181,
#   'label': 'Dec 24, 15',
#   'changeOverTime': 0.067271},
#  {'date': '2015-12-28',
#   'uClose': 115.95,
#   'uOpen': 116.42,
#   'uHigh': 116.83,
#   'uLow': 111.66,
#   'uVolume': 19562252,
#   'close': 115.59,
#   'open': 116.5,
#   'high': 113.69,
#   'low': 114.43,
#   'volume': 19820751,
#   'currency': '',
#   'change': -0.06,
#   'changePercent': -0.0548,
#   'label': 'Dec 28, 15',
#   'changeOverTime': 0.065885},
#  {'date': '2015-12-29',
#   'uClose': 118.1,
#   'uOpen': 118.36,
#   'uHigh': 116.71,
#   'uLow': 113.42,
#   'uVolume': 27793826,
#   'close': 115.4,
#   'open': 116.01,
#   'high': 114.87,
#   'low': 115.62,
#   'volume': 28704056,
#   'currency': '',
#   'change': 1.8,
#   'changePercent': 1.5953,
#   'label': 'Dec 29, 15',
#   'changeOverTime': 0.083715},
#  {'date': '2015-12-30',
#   'uClose': 116.2,
#   'uOpen': 119.68,
#   'uHigh': 117.45,
#   'uLow': 113.77,
#   'uVolume': 20189339,
#   'close': 117.82,
#   'open': 119.38,
#   'high': 114.75,
#   'low': 117.74,
#   'volume': 20266606,
#   'currency': '',
#   'change': -1.05,
#   'changePercent': -0.9307,
#   'label': 'Dec 30, 15',
#   'changeOverTime': 0.072753},
#  {'date': '2015-12-31',
#   'uClose': 116.73,
#   'uOpen': 114.69,
#   'uHigh': 117.06,
#   'uLow': 113.61,
#   'uVolume': 30441633,
#   'close': 116.23,
#   'open': 118.2,
#   'high': 114.95,
#   'low': 113.95,
#   'volume': 31356651,
#   'currency': '',
#   'change': -1.48,
#   'changePercent': -1.2748,
#   'label': 'Dec 31, 15',
#   'changeOverTime': 0.061568},
#  {'date': '2016-01-04',
#   'uClose': 113.3,
#   'uOpen': 111.65,
#   'uHigh': 111.2,
#   'uLow': 108.7,
#   'uVolume': 53262566,
#   'close': 114.3,
#   'open': 112.58,
#   'high': 110.7,
#   'low': 111.8,
#   'volume': 53087912,
#   'currency': '',
#   'change': -2.38,
#   'changePercent': -2.2081,
#   'label': 'Jan 4, 16',
#   'changeOverTime': 0.037537},
#  {'date': '2016-01-05',
#   'uClose': 114.52,
#   'uOpen': 112.06,
#   'uHigh': 110.6,
#   'uLow': 112.8,
#   'uVolume': 39323489,
#   'close': 113.7,
#   'open': 115.28,
#   'high': 110.87,
#   'low': 111.7,
#   'volume': 40196726,
#   'currency': '',
#   'change': -0.2,
#   'changePercent': -0.1766,
#   'label': 'Jan 5, 16',
#   'changeOverTime': 0.035794},
#  {'date': '2016-01-06',
#   'uClose': 109.73,
#   'uOpen': 112.74,
#   'uHigh': 109,
#   'uLow': 108.92,
#   'uVolume': 42237818,
#   'close': 112.12,
#   'open': 109.79,
#   'high': 111.41,
#   'low': 109.65,
#   'volume': 42812112,
#   'currency': '',
#   'change': -1.09,
#   'changePercent': -0.9984,
#   'label': 'Jan 6, 16',
#   'changeOverTime': 0.025888},
#  {'date': '2016-01-07',
#   'uClose': 107.31,
#   'uOpen': 106,
#   'uHigh': 108.45,
#   'uLow': 105.76,
#   'uVolume': 63773311,
#   'close': 109.62,
#   'open': 107.65,
#   'high': 108.31,
#   'low': 107.03,
#   'volume': 63618649,
#   'currency': '',
#   'change': -3.47,
#   'changePercent': -3.2728,
#   'label': 'Jan 7, 16',
#   'changeOverTime': -0.007316},
#  {'date': '2016-01-08',
#   'uClose': 104.28,
#   'uOpen': 108.41,
#   'uHigh': 108.66,
#   'uLow': 106.7,
#   'uVolume': 70275517,
#   'close': 106.93,
#   'open': 110.45,
#   'high': 108.2,
#   'low': 104.1,
#   'volume': 72222058,
#   'currency': '',
#   'change': -0.9,
#   'changePercent': -0.8344,
#   'label': 'Jan 8, 16',
#   'changeOverTime': -0.01617},
#  {'date': '2016-01-11',
#   'uClose': 106.48,
#   'uOpen': 108.2,
#   'uHigh': 109.06,
#   'uLow': 106.9,
#   'uVolume': 52445901,
#   'close': 105.48,
#   'open': 105.73,
#   'high': 108.16,
#   'low': 106.73,
#   'volume': 50025175,
#   'currency': '',
#   'change': 0.33,
#   'changePercent': 0.3121,
#   'label': 'Jan 11, 16',
#   'changeOverTime': -0.012684},
#  {'date': '2016-01-12',
#   'uClose': 107.3,
#   'uOpen': 105.82,
#   'uHigh': 109.61,
#   'uLow': 108.62,
#   'uVolume': 47517694,
#   'close': 106.88,
#   'open': 109.3,
#   'high': 107.01,
#   'low': 107.45,
#   'volume': 47055437,
#   'currency': '',
#   'change': 1.26,
#   'changePercent': 1.1861,
#   'label': 'Jan 12, 16',
#   'changeOverTime': -0.000973},
#  {'date': '2016-01-13',
#   'uClose': 105.1,
#   'uOpen': 109,
#   'uHigh': 109.03,
#   'uLow': 104.99,
#   'uVolume': 72069258,
#   'close': 104.1,
#   'open': 110,
#   'high': 108.59,
#   'low': 104.57,
#   'volume': 70002556,
#   'currency': '',
#   'change': -3.8,
#   'changePercent': -3.5351,
#   'label': 'Jan 13, 16',
#   'changeOverTime': -0.036296},
#  {'date': '2016-01-14',
#   'uClose': 108.92,
#   'uOpen': 105.1,
#   'uHigh': 107.31,
#   'uLow': 105.24,
#   'uVolume': 80707579,
#   'close': 105.05,
#   'open': 102.8,
#   'high': 110.06,
#   'low': 105.43,
#   'volume': 82249961,
#   'currency': '',
#   'change': 2.2,
#   'changePercent': 2.1844,
#   'label': 'Jan 14, 16',
#   'changeOverTime': -0.015484},
#  {'date': '2016-01-15',
#   'uClose': 101.02,
#   'uOpen': 101.25,
#   'uHigh': 101.99,
#   'uLow': 103.99,
#   'uVolume': 93899157,
#   'close': 105.77,
#   'open': 105.26,
#   'high': 105.04,
#   'low': 100.28,
#   'volume': 93058202,
#   'currency': '',
#   'change': -3.31,
#   'changePercent': -3.156,
#   'label': 'Jan 15, 16',
#   'changeOverTime': -0.046644},
#  {'date': '2016-01-19',
#   'uClose': 103.31,
#   'uOpen': 106.5,
#   'uHigh': 106.66,
#   'uLow': 102.39,
#   'uVolume': 58178510,
#   'close': 103.16,
#   'open': 106.5,
#   'high': 105.19,
#   'low': 100.26,
#   'volume': 59024206,
#   'currency': '',
#   'change': 0.22,
#   'changePercent': 0.2221,
#   'label': 'Jan 19, 16',
#   'changeOverTime': -0.043708},
#  {'date': '2016-01-20',
#   'uClose': 103.85,
#   'uOpen': 102.38,
#   'uHigh': 105.97,
#   'uLow': 97.89,
#   'uVolume': 90013533,
#   'close': 101.44,
#   'open': 99.96,
#   'high': 104.52,
#   'low': 100.49,
#   'volume': 88810179,
#   'currency': '',
#   'change': -0.31,
#   'changePercent': -0.321,
#   'label': 'Jan 20, 16',
#   'changeOverTime': -0.046855},
#  {'date': '2016-01-21',
#   'uClose': 104.75,
#   'uOpen': 101.86,
#   'uHigh': 105.52,
#   'uLow': 103.52,
#   'uVolume': 63517211,
#   'close': 104.44,
#   'open': 103.93,
#   'high': 103.24,
#   'low': 102.88,
#   'volume': 62843874,
#   'currency': '',
#   'change': 0.1,
#   'changePercent': 0.1018,
#   'label': 'Jan 21, 16',
#   'changeOverTime': -0.04539},
#  {'date': '2016-01-22',
#   'uClose': 108.2,
#   'uOpen': 104.26,
#   'uHigh': 108.04,
#   'uLow': 107.51,
#   'uVolume': 42972080,
#   'close': 107.18,
#   'open': 106.12,
#   'high': 108.72,
#   'low': 105.7,
#   'volume': 42727829,
#   'currency': '',
#   'change': 3.04,
#   'changePercent': 2.9708,
#   'label': 'Jan 22, 16',
#   'changeOverTime': -0.018567},
#  {'date': '2016-01-25',
#   'uClose': 105.67,
#   'uOpen': 106.55,
#   'uHigh': 108.5,
#   'uLow': 103.61,
#   'uVolume': 38936929,
#   'close': 106.56,
#   'open': 105.9,
#   'high': 106,
#   'low': 106.27,
#   'volume': 40325530,
#   'currency': '',
#   'change': -1.61,
#   'changePercent': -1.5388,
#   'label': 'Jan 25, 16',
#   'changeOverTime': -0.032351},
#  {'date': '2016-01-26',
#   'uClose': 108.12,
#   'uOpen': 104.19,
#   'uHigh': 107.88,
#   'uLow': 102.11,
#   'uVolume': 37347778,
#   'close': 105.3,
#   'open': 105.72,
#   'high': 106.01,
#   'low': 105.73,
#   'volume': 36724054,
#   'currency': '',
#   'change': 0.95,
#   'changePercent': 0.9006,
#   'label': 'Jan 26, 16',
#   'changeOverTime': -0.023913},
#  {'date': '2016-01-27',
#   'uClose': 105.27,
#   'uOpen': 103.03,
#   'uHigh': 103.81,
#   'uLow': 101.35,
#   'uVolume': 54670290,
#   'close': 103.95,
#   'open': 104.08,
#   'high': 105.18,
#   'low': 101.4,
#   'volume': 55988826,
#   'currency': '',
#   'change': -2.62,
#   'changePercent': -2.5194,
#   'label': 'Jan 27, 16',
#   'changeOverTime': -0.049472},
#  {'date': '2016-01-28',
#   'uClose': 106,
#   'uOpen': 103.69,
#   'uHigh': 107.21,
#   'uLow': 103.34,
#   'uVolume': 49518101,
#   'close': 103,
#   'open': 104.9,
#   'high': 104.32,
#   'low': 100.42,
#   'volume': 49294895,
#   'currency': '',
#   'change': 1.46,
#   'changePercent': 1.4565,
#   'label': 'Jan 28, 16',
#   'changeOverTime': -0.036106},
#  {'date': '2016-01-29',
#   'uClose': 106.76,
#   'uOpen': 107,
#   'uHigh': 104.41,
#   'uLow': 104.31,
#   'uVolume': 56308668,
#   'close': 105.61,
#   'open': 102,
#   'high': 109.09,
#   'low': 103.39,
#   'volume': 55329947,
#   'currency': '',
#   'change': 2.16,
#   'changePercent': 2.1076,
#   'label': 'Jan 29, 16',
#   'changeOverTime': -0.014354},
#  {'date': '2016-02-01',
#   'uClose': 106.16,
#   'uOpen': 107.01,
#   'uHigh': 105.5,
#   'uLow': 105.44,
#   'uVolume': 33783671,
#   'close': 109.16,
#   'open': 106.41,
#   'high': 108.2,
#   'low': 105.85,
#   'volume': 34347035,
#   'currency': '',
#   'change': 0.28,
#   'changePercent': 0.271,
#   'label': 'Feb 1, 16',
#   'changeOverTime': -0.011723},
#  {'date': '2016-02-02',
#   'uClose': 102.69,
#   'uOpen': 108.3,
#   'uHigh': 106.88,
#   'uLow': 102.52,
#   'uVolume': 46590539,
#   'close': 105.13,
#   'open': 104.84,
#   'high': 104.96,
#   'low': 103.39,
#   'volume': 46229232,
#   'currency': '',
#   'change': -2.37,
#   'changePercent': -2.2657,
#   'label': 'Feb 2, 16',
#   'changeOverTime': -0.033284},
#  {'date': '2016-02-03',
#   'uClose': 102.91,
#   'uOpen': 105.9,
#   'uHigh': 104.58,
#   'uLow': 104.41,
#   'uVolume': 62907724,
#   'close': 104.48,
#   'open': 107.1,
#   'high': 104.2,
#   'low': 102.75,
#   'volume': 62138066,
#   'currency': '',
#   'change': -0.5,
#   'changePercent': -0.4908,
#   'label': 'Feb 3, 16',
#   'changeOverTime': -0.038583},
#  {'date': '2016-02-04',
#   'uClose': 101.93,
#   'uOpen': 102.68,
#   'uHigh': 107.33,
#   'uLow': 105.38,
#   'uVolume': 50226809,
#   'close': 102.6,
#   'open': 103.09,
#   'high': 103.97,
#   'low': 101.76,
#   'volume': 50530471,
#   'currency': '',
#   'change': -0.01,
#   'changePercent': -0.0099,
#   'label': 'Feb 4, 16',
#   'changeOverTime': -0.03845},
#  {'date': '2016-02-05',
#   'uClose': 102.75,
#   'uOpen': 106.17,
#   'uHigh': 106.26,
#   'uLow': 101.7,
#   'uVolume': 70831693,
#   'close': 98.71,
#   'open': 104.27,
#   'high': 104.65,
#   'low': 99.6,
#   'volume': 73372680,
#   'currency': '',
#   'change': -3.67,
#   'changePercent': -3.4758,
#   'label': 'Feb 5, 16',
#   'changeOverTime': -0.071417},
#  {'date': '2016-02-08',
#   'uClose': 97.07,
#   'uOpen': 101.12,
#   'uHigh': 98.66,
#   'uLow': 97.46,
#   'uVolume': 92580985,
#   'close': 100.56,
#   'open': 97.98,
#   'high': 98.26,
#   'low': 97.84,
#   'volume': 94554572,
#   'currency': '',
#   'change': -1.5,
#   'changePercent': -1.5468,
#   'label': 'Feb 8, 16',
#   'changeOverTime': -0.089582},
#  {'date': '2016-02-09',
#   'uClose': 99.6,
#   'uOpen': 99.67,
#   'uHigh': 101.05,
#   'uLow': 97.4,
#   'uVolume': 76101024,
#   'close': 96.81,
#   'open': 99.03,
#   'high': 101.11,
#   'low': 96.98,
#   'volume': 75761150,
#   'currency': '',
#   'change': -0.3,
#   'changePercent': -0.3161,
#   'label': 'Feb 9, 16',
#   'changeOverTime': -0.088974},
#  {'date': '2016-02-10',
#   'uClose': 96.88,
#   'uOpen': 101.1,
#   'uHigh': 99.55,
#   'uLow': 97.45,
#   'uVolume': 61620192,
#   'close': 98.06,
#   'open': 99.1,
#   'high': 101.93,
#   'low': 96.74,
#   'volume': 61751374,
#   'currency': '',
#   'change': 0.38,
#   'changePercent': 0.3863,
#   'label': 'Feb 10, 16',
#   'changeOverTime': -0.08658},
#  {'date': '2016-02-11',
#   'uClose': 98.73,
#   'uOpen': 98.73,
#   'uHigh': 97.37,
#   'uLow': 96.83,
#   'uVolume': 77006711,
#   'close': 99.14,
#   'open': 98.69,
#   'high': 101.21,
#   'low': 98.03,
#   'volume': 78248609,
#   'currency': '',
#   'change': -0.15,
#   'changePercent': -0.1509,
#   'label': 'Feb 11, 16',
#   'changeOverTime': -0.086977},
#  {'date': '2016-02-12',
#   'uClose': 101.66,
#   'uOpen': 100.07,
#   'uHigh': 101.01,
#   'uLow': 100.37,
#   'uVolume': 49202904,
#   'close': 102.92,
#   'open': 98.47,
#   'high': 99.32,
#   'low': 100.84,
#   'volume': 50113833,
#   'currency': '',
#   'change': 1.52,
#   'changePercent': 1.5471,
#   'label': 'Feb 12, 16',
#   'changeOverTime': -0.07258},
#  {'date': '2016-02-16',
#   'uClose': 102.18,
#   'uOpen': 104.1,
#   'uHigh': 100.71,
#   'uLow': 101.29,
#   'uVolume': 42093109,
#   'close': 102.78,
#   'open': 101.04,
#   'high': 103.92,
#   'low': 102.31,
#   'volume': 41954124,
#   'currency': '',
#   'change': 2.31,
#   'changePercent': 2.289,
#   'label': 'Feb 16, 16',
#   'changeOverTime': -0.053534},
#  {'date': '2016-02-17',
#   'uClose': 102.7,
#   'uOpen': 103.93,
#   'uHigh': 104.04,
#   'uLow': 100.9,
#   'uVolume': 41864491,
#   'close': 107.3,
#   'open': 104.73,
#   'high': 104.06,
#   'low': 103.2,
#   'volume': 43169628,
#   'currency': '',
#   'change': 2.29,
#   'changePercent': 2.3271,
#   'label': 'Feb 17, 16',
#   'changeOverTime': -0.030099},
#  {'date': '2016-02-18',
#   'uClose': 105.16,
#   'uOpen': 104.88,
#   'uHigh': 103.3,
#   'uLow': 102.2,
#   'uVolume': 40077759,
#   'close': 104.49,
#   'open': 105.88,
#   'high': 107.43,
#   'low': 105.2,
#   'volume': 39412327,
#   'currency': '',
#   'change': -1.18,
#   'changePercent': -1.1506,
#   'label': 'Feb 18, 16',
#   'changeOverTime': -0.042498},
#  {'date': '2016-02-19',
#   'uClose': 102.33,
#   'uOpen': 101.79,
#   'uHigh': 102.36,
#   'uLow': 102.06,
#   'uVolume': 29118362,
#   'close': 103.46,
#   'open': 103.04,
#   'high': 104.71,
#   'low': 102.87,
#   'volume': 29372293,
#   'currency': '',
#   'change': 0.3,
#   'changePercent': 0.3074,
#   'label': 'Feb 19, 16',
#   'changeOverTime': -0.039302},
#  {'date': '2016-02-22',
#   'uClose': 106.67,
#   'uOpen': 104.32,
#   'uHigh': 104.21,
#   'uLow': 106.11,
#   'uVolume': 24668976,
#   'close': 104.05,
#   'open': 103.84,
#   'high': 103.83,
#   'low': 104.18,
#   'volume': 24165951,
#   'currency': '',
#   'change': 1.7,
#   'changePercent': 1.6464,
#   'label': 'Feb 22, 16',
#   'changeOverTime': -0.02302},
#  {'date': '2016-02-23',
#   'uClose': 102.86,
#   'uOpen': 104.62,
#   'uHigh': 104.19,
#   'uLow': 103.77,
#   'uVolume': 31067294,
#   'close': 105.61,
#   'open': 107.69,
#   'high': 106.35,
#   'low': 104.62,
#   'volume': 30379335,
#   'currency': '',
#   'change': -1.7,
#   'changePercent': -1.66,
#   'label': 'Feb 23, 16',
#   'changeOverTime': -0.039582},
#  {'date': '2016-02-24',
#   'uClose': 106.05,
#   'uOpen': 103.29,
#   'uHigh': 105.88,
#   'uLow': 101.69,
#   'uVolume': 42095143,
#   'close': 107.51,
#   'open': 102.09,
#   'high': 105.42,
#   'low': 103.75,
#   'volume': 41587909,
#   'currency': '',
#   'change': 1.01,
#   'changePercent': 0.9943,
#   'label': 'Feb 24, 16',
#   'changeOverTime': -0.02955},
#  {'date': '2016-02-25',
#   'uClose': 108.03,
#   'uOpen': 106.99,
#   'uHigh': 107.76,
#   'uLow': 104.99,
#   'uVolume': 30662945,
#   'close': 107.42,
#   'open': 107.85,
#   'high': 103.9,
#   'low': 101.9,
#   'volume': 29932599,
#   'currency': '',
#   'change': 1.04,
#   'changePercent': 1.0186,
#   'label': 'Feb 25, 16',
#   'changeOverTime': -0.0202},
#  {'date': '2016-02-26',
#   'uClose': 104.76,
#   'uOpen': 109.14,
#   'uHigh': 104.8,
#   'uLow': 104.63,
#   'uVolume': 32168058,
#   'close': 106.19,
#   'open': 109.1,
#   'high': 108.85,
#   'low': 107.53,
#   'volume': 31006564,
#   'currency': '',
#   'change': -0.13,
#   'changePercent': -0.1304,
#   'label': 'Feb 26, 16',
#   'changeOverTime': -0.02143},
#  {'date': '2016-02-29',
#   'uClose': 104.5,
#   'uOpen': 103.73,
#   'uHigh': 107.1,
#   'uLow': 102.8,
#   'uVolume': 27707186,
#   'close': 106.1,
#   'open': 108.31,
#   'high': 109.2,
#   'low': 102.8,
#   'volume': 28864110,
#   'currency': '',
#   'change': -0.96,
#   'changePercent': -0.9016,
#   'label': 'Feb 29, 16',
#   'changeOverTime': -0.030225},
#  {'date': '2016-03-01',
#   'uClose': 106.83,
#   'uOpen': 103.52,
#   'uHigh': 108.6,
#   'uLow': 105.18,
#   'uVolume': 39037911,
#   'close': 106.94,
#   'open': 107.52,
#   'high': 107.91,
#   'low': 107.22,
#   'volume': 37984617,
#   'currency': '',
#   'change': 3.36,
#   'changePercent': 3.305,
#   'label': 'Mar 1, 16',
#   'changeOverTime': 0.00144},
#  {'date': '2016-03-02',
#   'uClose': 105.88,
#   'uOpen': 110.13,
#   'uHigh': 108.51,
#   'uLow': 108.79,
#   'uVolume': 30068966,
#   'close': 106.51,
#   'open': 110.23,
#   'high': 110.43,
#   'low': 105.71,
#   'volume': 29948718,
#   'currency': '',
#   'change': 0.04,
#   'changePercent': 0.0378,
#   'label': 'Mar 2, 16',
#   'changeOverTime': 0.001872},
#  {'date': '2016-03-03',
#   'uClose': 105.72,
#   'uOpen': 107.43,
#   'uHigh': 110.08,
#   'uLow': 108.82,
#   'uVolume': 25651033,
#   'close': 109.27,
#   'open': 105.95,
#   'high': 107.45,
#   'low': 106.46,
#   'volume': 25548171,
#   'currency': '',
#   'change': -0.2,
#   'changePercent': -0.191,
#   'label': 'Mar 3, 16',
#   'changeOverTime': -0.0001},
#  {'date': '2016-03-04',
#   'uClose': 110.82,
#   'uOpen': 107.89,
#   'uHigh': 111.39,
#   'uLow': 106.33,
#   'uVolume': 32250580,
#   'close': 106.55,
#   'open': 108.35,
#   'high': 107.44,
#   'low': 108.34,
#   'volume': 31693591,
#   'currency': '',
#   'change': 0.04,
#   'changePercent': 0.0393,
#   'label': 'Mar 4, 16',
#   'changeOverTime': 0.000294},
#  {'date': '2016-03-07',
#   'uClose': 107.53,
#   'uOpen': 108.64,
#   'uHigh': 109.44,
#   'uLow': 105.32,
#   'uVolume': 25888298,
#   'close': 109.87,
#   'open': 105.35,
#   'high': 106.27,
#   'low': 107.39,
#   'volume': 26937430,
#   'currency': '',
#   'change': -0.68,
#   'changePercent': -0.6265,
#   'label': 'Mar 7, 16',
#   'changeOverTime': -0.005988},
#  {'date': '2016-03-08',
#   'uClose': 104.84,
#   'uOpen': 106.8,
#   'uHigh': 108.56,
#   'uLow': 106.53,
#   'uVolume': 29241076,
#   'close': 107.76,
#   'open': 108.7,
#   'high': 107.41,
#   'low': 105.02,
#   'volume': 28979858,
#   'currency': '',
#   'change': -0.87,
#   'changePercent': -0.8448,
#   'label': 'Mar 8, 16',
#   'changeOverTime': -0.01413},
#  {'date': '2016-03-09',
#   'uClose': 105.15,
#   'uOpen': 104.59,
#   'uHigh': 107.14,
#   'uLow': 105.68,
#   'uVolume': 32593702,
#   'close': 107.61,
#   'open': 109.51,
#   'high': 108.92,
#   'low': 108.8,
#   'volume': 31649186,
#   'currency': '',
#   'change': 0.69,
#   'changePercent': 0.6471,
#   'label': 'Mar 9, 16',
#   'changeOverTime': -0.008044},
#  {'date': '2016-03-10',
#   'uClose': 109.45,
#   'uOpen': 108.78,
#   'uHigh': 107.86,
#   'uLow': 107.74,
#   'uVolume': 46389588,
#   'close': 108.69,
#   'open': 106.51,
#   'high': 106.94,
#   'low': 105.74,
#   'volume': 46990461,
#   'currency': '',
#   'change': -0.16,
#   'changePercent': -0.1531,
#   'label': 'Mar 10, 16',
#   'changeOverTime': -0.009427},
#  {'date': '2016-03-11',
#   'uClose': 111.15,
#   'uOpen': 106.5,
#   'uHigh': 110.13,
#   'uLow': 106.89,
#   'uVolume': 32396088,
#   'close': 111.08,
#   'open': 106.6,
#   'high': 110.2,
#   'low': 108.2,
#   'volume': 32789357,
#   'currency': '',
#   'change': 1.89,
#   'changePercent': 1.7765,
#   'label': 'Mar 11, 16',
#   'changeOverTime': 0.008307},
#  {'date': '2016-03-14',
#   'uClose': 111.02,
#   'uOpen': 106.71,
#   'uHigh': 108.42,
#   'uLow': 111.13,
#   'uVolume': 26352642,
#   'close': 111.23,
#   'open': 110.75,
#   'high': 111.91,
#   'low': 106.96,
#   'volume': 26154117,
#   'currency': '',
#   'change': 0.18,
#   'changePercent': 0.172,
#   'label': 'Mar 14, 16',
#   'changeOverTime': 0.00989},
#  {'date': '2016-03-15',
#   'uClose': 111.22,
#   'uOpen': 110.9,
#   'uHigh': 107.05,
#   'uLow': 106.47,
#   'uVolume': 27452319,
#   'close': 107.87,
#   'open': 108.35,
#   'high': 108.68,
#   'low': 106.4,
#   'volume': 27702281,
#   'currency': '',
#   'change': -0.04,
#   'changePercent': -0.0381,
#   'label': 'Mar 15, 16',
#   'changeOverTime': 0.009711},
#  {'date': '2016-03-16',
#   'uClose': 111.24,
#   'uOpen': 111.01,
#   'uHigh': 113.16,
#   'uLow': 109.31,
#   'uVolume': 32081738,
#   'close': 111.82,
#   'open': 108.83,
#   'high': 111.88,
#   'low': 110.71,
#   'volume': 32618759,
#   'currency': '',
#   'change': 0.99,
#   'changePercent': 0.8928,
#   'label': 'Mar 16, 16',
#   'changeOverTime': 0.018726},
#  {'date': '2016-03-17',
#   'uClose': 107.92,
#   'uOpen': 109.3,
#   'uHigh': 109.68,
#   'uLow': 107.73,
#   'uVolume': 29802690,
#   'close': 110.16,
#   'open': 112.34,
#   'high': 112.3,
#   'low': 109.09,
#   'volume': 31103156,
#   'currency': '',
#   'change': -0.06,
#   'changePercent': -0.0561,
#   'label': 'Mar 17, 16',
#   'changeOverTime': 0.018336},
#  {'date': '2016-03-18',
#   'uClose': 111.21,
#   'uOpen': 109.77,
#   'uHigh': 107.69,
#   'uLow': 108.9,
#   'uVolume': 38015795,
#   'close': 112.54,
#   'open': 112.05,
#   'high': 110.12,
#   'low': 106.8,
#   'volume': 38808953,
#   'currency': '',
#   'change': -0.15,
#   'changePercent': -0.1427,
#   'label': 'Mar 18, 16',
#   'changeOverTime': 0.016961},
#  {'date': '2016-03-21',
#   'uClose': 109.2,
#   'uOpen': 111.55,
#   'uHigh': 110.27,
#   'uLow': 109.89,
#   'uVolume': 17947769,
#   'close': 111.46,
#   'open': 108.33,
#   'high': 110.18,
#   'low': 109.92,
#   'volume': 17446644,
#   'currency': '',
#   'change': 0.43,
#   'changePercent': 0.3919,
#   'label': 'Mar 21, 16',
#   'changeOverTime': 0.021268},
#  {'date': '2016-03-22',
#   'uClose': 111.7,
#   'uOpen': 108.86,
#   'uHigh': 111.12,
#   'uLow': 111.04,
#   'uVolume': 19040979,
#   'close': 109.14,
#   'open': 112.51,
#   'high': 113.68,
#   'low': 109.29,
#   'volume': 19380951,
#   'currency': '',
#   'change': 0.33,
#   'changePercent': 0.3082,
#   'label': 'Mar 22, 16',
#   'changeOverTime': 0.024599},
#  {'date': '2016-03-23',
#   'uClose': 108.88,
#   'uOpen': 112.66,
#   'uHigh': 108.77,
#   'uLow': 107.96,
#   'uVolume': 21673312,
#   'close': 107.35,
#   'open': 107.94,
#   'high': 110.22,
#   'low': 109.67,
# ...
#   'uClose': 191.3,
#   'uOpen': 192.62,
#   'uHigh': 187.4,
#   'uLow': 186.19,
#   'uVolume': 41510196,
#   'close': 190.6,
#   'open': 189.18,
#   'high': 193.2,
#   'low': 183.59,
#   'volume': 42983984,
#   'currency': '',
#   'change': 0.26,
#   'changePercent': 0.1406,
#   'label': 'Jun 11, 19',
#   'changeOverTime': 0.76494},
#  {'date': '2019-06-12',
#   'uClose': 186.22,
#   'uOpen': 186.79,
#   'uHigh': 186.21,
#   'uLow': 186,
#   'uVolume': 27942969,
#   'close': 187.14,
#   'open': 188.75,
#   'high': 186.05,
#   'low': 187,
#   'volume': 28963590,
#   'currency': '',
#   'change': -1.1,
#   'changePercent': -0.605,
#   'label': 'Jun 12, 19',
#   'changeOverTime': 0.727803},
#  {'date': '2019-06-13',
#   'uClose': 187.97,
#   'uOpen': 190.43,
#   'uHigh': 191.74,
#   'uLow': 183.5,
#   'uVolume': 23846357,
#   'close': 187.5,
#   'open': 190.17,
#   'high': 191.6,
#   'low': 187.4,
#   'volume': 23931914,
#   'currency': '',
#   'change': 1.13,
#   'changePercent': 0.6077,
#   'label': 'Jun 13, 19',
#   'changeOverTime': 0.768356},
#  {'date': '2019-06-14',
#   'uClose': 191.26,
#   'uOpen': 186.7,
#   'uHigh': 189.53,
#   'uLow': 185.96,
#   'uVolume': 23540060,
#   'close': 184.83,
#   'open': 190.46,
#   'high': 185.83,
#   'low': 183.5,
#   'volume': 23688840,
#   'currency': '',
#   'change': -0.81,
#   'changePercent': -0.4288,
#   'label': 'Jun 14, 19',
#   'changeOverTime': 0.737468},
#  {'date': '2019-06-17',
#   'uClose': 185.87,
#   'uOpen': 187.94,
#   'uHigh': 186.7,
#   'uLow': 190.33,
#   'uVolume': 21149424,
#   'close': 184.97,
#   'open': 190.84,
#   'high': 184.6,
#   'low': 189.43,
#   'volume': 20884766,
#   'currency': '',
#   'change': 1.1,
#   'changePercent': 0.631,
#   'label': 'Jun 17, 19',
#   'changeOverTime': 0.76639},
#  {'date': '2019-06-18',
#   'uClose': 194.49,
#   'uOpen': 189.1,
#   'uHigh': 187.83,
#   'uLow': 193.27,
#   'uVolume': 49925973,
#   'close': 189,
#   'open': 194.48,
#   'high': 195.95,
#   'low': 188.67,
#   'volume': 48612364,
#   'currency': '',
#   'change': 2.78,
#   'changePercent': 1.5021,
#   'label': 'Jun 18, 19',
#   'changeOverTime': 0.800542},
#  {'date': '2019-06-19',
#   'uClose': 189.69,
#   'uOpen': 193.06,
#   'uHigh': 196.43,
#   'uLow': 186.43,
#   'uVolume': 31875016,
#   'close': 193.77,
#   'open': 191.5,
#   'high': 189.25,
#   'low': 191.9,
#   'volume': 32857737,
#   'currency': '',
#   'change': 0.7,
#   'changePercent': 0.3816,
#   'label': 'Jun 19, 19',
#   'changeOverTime': 0.804502},
#  {'date': '2019-06-20',
#   'uClose': 193.27,
#   'uOpen': 193.47,
#   'uHigh': 192.54,
#   'uLow': 191.4,
#   'uVolume': 41762655,
#   'close': 196.41,
#   'open': 197.32,
#   'high': 195.55,
#   'low': 195.06,
#   'volume': 41197786,
#   'currency': '',
#   'change': 1.79,
#   'changePercent': 0.934,
#   'label': 'Jun 20, 19',
#   'changeOverTime': 0.796807},
#  {'date': '2019-06-21',
#   'uClose': 196.9,
#   'uOpen': 192.75,
#   'uHigh': 197.3,
#   'uLow': 197.15,
#   'uVolume': 40076543,
#   'close': 196.01,
#   'open': 191.85,
#   'high': 195.69,
#   'low': 190.49,
#   'volume': 41442093,
#   'currency': '',
#   'change': -0.29,
#   'changePercent': -0.1496,
#   'label': 'Jun 21, 19',
#   'changeOverTime': 0.79232},
#  {'date': '2019-06-24',
#   'uClose': 196.6,
#   'uOpen': 197.61,
#   'uHigh': 197.61,
#   'uLow': 196,
#   'uVolume': 20059190,
#   'close': 191.85,
#   'open': 194.51,
#   'high': 197.66,
#   'low': 191.53,
#   'volume': 20107202,
#   'currency': '',
#   'change': -0.42,
#   'changePercent': -0.2192,
#   'label': 'Jun 24, 19',
#   'changeOverTime': 0.819527},
#  {'date': '2019-06-25',
#   'uClose': 190.23,
#   'uOpen': 193.75,
#   'uHigh': 196.01,
#   'uLow': 192.31,
#   'uVolume': 35368928,
#   'close': 188.01,
#   'open': 197.37,
#   'high': 193.45,
#   'low': 186.5,
#   'volume': 34296083,
#   'currency': '',
#   'change': -3.3,
#   'changePercent': -1.7504,
#   'label': 'Jun 25, 19',
#   'changeOverTime': 0.775978},
#  {'date': '2019-06-26',
#   'uClose': 193.5,
#   'uOpen': 191.52,
#   'uHigh': 190.8,
#   'uLow': 186.84,
#   'uVolume': 23661682,
#   'close': 193.8,
#   'open': 194.08,
#   'high': 194.17,
#   'low': 193.86,
#   'volume': 22746397,
#   'currency': '',
#   'change': 0.89,
#   'changePercent': 0.479,
#   'label': 'Jun 26, 19',
#   'changeOverTime': 0.787152},
#  {'date': '2019-06-27',
#   'uClose': 186.7,
#   'uOpen': 191.63,
#   'uHigh': 192.59,
#   'uLow': 189.21,
#   'uVolume': 20167235,
#   'close': 186.7,
#   'open': 193.52,
#   'high': 192.78,
#   'low': 193.58,
#   'volume': 20053358,
#   'currency': '',
#   'change': 0.72,
#   'changePercent': 0.4011,
#   'label': 'Jun 27, 19',
#   'changeOverTime': 0.79051},
#  {'date': '2019-06-28',
#   'uClose': 189.85,
#   'uOpen': 190.98,
#   'uHigh': 188.93,
#   'uLow': 195.19,
#   'uVolume': 22174747,
#   'close': 195.99,
#   'open': 187.39,
#   'high': 192.59,
#   'low': 187.63,
#   'volume': 21823005,
#   'currency': '',
#   'change': 0.24,
#   'changePercent': 0.1351,
#   'label': 'Jun 28, 19',
#   'changeOverTime': 0.779787},
#  {'date': '2019-07-01',
#   'uClose': 198.13,
#   'uOpen': 195.2,
#   'uHigh': 193.44,
#   'uLow': 197.36,
#   'uVolume': 31281082,
#   'close': 192.5,
#   'open': 197.9,
#   'high': 190.99,
#   'low': 197.12,
#   'volume': 32071844,
#   'currency': '',
#   'change': 2.55,
#   'changePercent': 1.3752,
#   'label': 'Jul 1, 19',
#   'changeOverTime': 0.791999},
#  {'date': '2019-07-02',
#   'uClose': 195.11,
#   'uOpen': 194.53,
#   'uHigh': 192.76,
#   'uLow': 189.16,
#   'uVolume': 18813778,
#   'close': 192.71,
#   'open': 198.35,
#   'high': 190.44,
#   'low': 193.08,
#   'volume': 18887876,
#   'currency': '',
#   'change': 0.78,
#   'changePercent': 0.4113,
#   'label': 'Jul 2, 19',
#   'changeOverTime': 0.809952},
#  {'date': '2019-07-03',
#   'uClose': 200.38,
#   'uOpen': 199.48,
#   'uHigh': 195.59,
#   'uLow': 199.62,
#   'uVolume': 16470589,
#   'close': 195.89,
#   'open': 193.99,
#   'high': 193.3,
#   'low': 192.73,
#   'volume': 16379309,
#   'currency': '',
#   'change': 1.45,
#   'changePercent': 0.7557,
#   'label': 'Jul 3, 19',
#   'changeOverTime': 0.833497},
#  {'date': '2019-07-05',
#   'uClose': 194.69,
#   'uOpen': 198.37,
#   'uHigh': 198.7,
#   'uLow': 198.38,
#   'uVolume': 22329451,
#   'close': 198.91,
#   'open': 192.44,
#   'high': 199.9,
#   'low': 189.82,
#   'volume': 22330945,
#   'currency': '',
#   'change': -0.39,
#   'changePercent': -0.2048,
#   'label': 'Jul 5, 19',
#   'changeOverTime': 0.815973},
#  {'date': '2019-07-08',
#   'uClose': 192.67,
#   'uOpen': 195.04,
#   'uHigh': 192.78,
#   'uLow': 198.11,
#   'uVolume': 17744643,
#   'close': 196.58,
#   'open': 191.51,
#   'high': 193.03,
#   'low': 196.7,
#   'volume': 17927245,
#   'currency': '',
#   'change': -1.4,
#   'changePercent': -0.7197,
#   'label': 'Jul 8, 19',
#   'changeOverTime': 0.811803},
#  {'date': '2019-07-09',
#   'uClose': 193.95,
#   'uOpen': 193.12,
#   'uHigh': 196.3,
#   'uLow': 190.59,
#   'uVolume': 19266455,
#   'close': 197.44,
#   'open': 193.15,
#   'high': 196.1,
#   'low': 193.33,
#   'volume': 20145514,
#   'currency': '',
#   'change': 0.95,
#   'changePercent': 0.5125,
#   'label': 'Jul 9, 19',
#   'changeOverTime': 0.841145},
#  {'date': '2019-07-10',
#   'uClose': 195.38,
#   'uOpen': 194.93,
#   'uHigh': 199.8,
#   'uLow': 198.56,
#   'uVolume': 29559057,
#   'close': 200.87,
#   'open': 197.97,
#   'high': 198.89,
#   'low': 192.19,
#   'volume': 29239764,
#   'currency': '',
#   'change': 2,
#   'changePercent': 1.0365,
#   'label': 'Jul 10, 19',
#   'changeOverTime': 0.831225},
#  {'date': '2019-07-11',
#   'uClose': 199.55,
#   'uOpen': 199.24,
#   'uHigh': 195.15,
#   'uLow': 192.22,
#   'uVolume': 24084494,
#   'close': 193.7,
#   'open': 200.4,
#   'high': 201,
#   'low': 193.75,
#   'volume': 24447664,
#   'currency': '',
#   'change': -0.14,
#   'changePercent': -0.0747,
#   'label': 'Jul 11, 19',
#   'changeOverTime': 0.823614},
#  {'date': '2019-07-12',
#   'uClose': 195.54,
#   'uOpen': 200.73,
#   'uHigh': 198.69,
#   'uLow': 196.65,
#   'uVolume': 20735412,
#   'close': 201.76,
#   'open': 197.21,
#   'high': 196.39,
#   'low': 199.74,
#   'volume': 20257227,
#   'currency': '',
#   'change': 1.14,
#   'changePercent': 0.6004,
#   'label': 'Jul 12, 19',
#   'changeOverTime': 0.844074},
#  {'date': '2019-07-15',
#   'uClose': 195.83,
#   'uOpen': 202.04,
#   'uHigh': 203.19,
#   'uLow': 197.62,
#   'uVolume': 16056858,
#   'close': 200,
#   'open': 201.52,
#   'high': 201.45,
#   'low': 202.41,
#   'volume': 15918747,
#   'currency': '',
#   'change': 0.63,
#   'changePercent': 0.3334,
#   'label': 'Jul 15, 19',
#   'changeOverTime': 0.839513},
#  {'date': '2019-07-16',
#   'uClose': 193.39,
#   'uOpen': 202.63,
#   'uHigh': 195.88,
#   'uLow': 199.01,
#   'uVolume': 20918018,
#   'close': 198.88,
#   'open': 197.58,
#   'high': 196.75,
#   'low': 198.56,
#   'volume': 20610216,
#   'currency': '',
#   'change': -1,
#   'changePercent': -0.5299,
#   'label': 'Jul 16, 19',
#   'changeOverTime': 0.841778},
#  {'date': '2019-07-17',
#   'uClose': 199.2,
#   'uOpen': 196.7,
#   'uHigh': 198.18,
#   'uLow': 197.88,
#   'uVolume': 17282488,
#   'close': 193.8,
#   'open': 196.3,
#   'high': 199.58,
#   'low': 195.44,
#   'volume': 16900542,
#   'currency': '',
#   'change': -0.96,
#   'changePercent': -0.5146,
#   'label': 'Jul 17, 19',
#   'changeOverTime': 0.855942},
#  {'date': '2019-07-18',
#   'uClose': 201.75,
#   'uOpen': 196,
#   'uHigh': 200.8,
#   'uLow': 198.12,
#   'uVolume': 29175963,
#   'close': 201.98,
#   'open': 196.8,
#   'high': 200.23,
#   'low': 193.28,
#   'volume': 30225492,
#   'currency': '',
#   'change': 0.23,
#   'changePercent': 0.1148,
#   'label': 'Jul 18, 19',
#   'changeOverTime': 0.824823},
#  {'date': '2019-07-19',
#   'uClose': 192.81,
#   'uOpen': 196.32,
#   'uHigh': 198.97,
#   'uLow': 199.28,
#   'uVolume': 29976020,
#   'close': 195.11,
#   'open': 196.35,
#   'high': 194.67,
#   'low': 196.13,
#   'volume': 29784347,
#   'currency': '',
#   'change': -1.44,
#   'changePercent': -0.7523,
#   'label': 'Jul 19, 19',
#   'changeOverTime': 0.848498},
#  {'date': '2019-07-22',
#   'uClose': 199.87,
#   'uOpen': 194.6,
#   'uHigh': 200.04,
#   'uLow': 195.2,
#   'uVolume': 19072551,
#   'close': 199.59,
#   'open': 192.1,
#   'high': 199.01,
#   'low': 192.56,
#   'volume': 19738968,
#   'currency': '',
#   'change': 1.55,
#   'changePercent': 0.8314,
#   'label': 'Jul 22, 19',
#   'changeOverTime': 0.82693},
#  {'date': '2019-07-23',
#   'uClose': 194.6,
#   'uOpen': 202.23,
#   'uHigh': 201.36,
#   'uLow': 194.54,
#   'uVolume': 24754752,
#   'close': 199.81,
#   'open': 199.57,
#   'high': 198.2,
#   'low': 199.99,
#   'volume': 23973845,
#   'currency': '',
#   'change': 1.28,
#   'changePercent': 0.6847,
#   'label': 'Jul 23, 19',
#   'changeOverTime': 0.862958},
#  {'date': '2019-07-24',
#   'uClose': 199.98,
#   'uOpen': 195.69,
#   'uHigh': 196.69,
#   'uLow': 193.56,
#   'uVolume': 21288558,
#   'close': 197.23,
#   'open': 193.2,
#   'high': 200.65,
#   'low': 201.73,
#   'volume': 21012896,
#   'currency': '',
#   'change': 1.42,
#   'changePercent': 0.7231,
#   'label': 'Jul 24, 19',
#   'changeOverTime': 0.883744},
#  {'date': '2019-07-25',
#   'uClose': 201.8,
#   'uOpen': 197.63,
#   'uHigh': 197.15,
#   'uLow': 197.99,
#   'uVolume': 23690227,
#   'close': 197.9,
#   'open': 200.9,
#   'high': 195.95,
#   'low': 193.66,
#   'volume': 23857401,
#   'currency': '',
#   'change': -1.9,
#   'changePercent': -0.96,
#   'label': 'Jul 25, 19',
#   'changeOverTime': 0.864178},
#  {'date': '2019-07-26',
#   'uClose': 198.23,
#   'uOpen': 196.2,
#   'uHigh': 204.52,
#   'uLow': 202.94,
#   'uVolume': 20501463,
#   'close': 200.97,
#   'open': 202.95,
#   'high': 201.06,
#   'low': 199.95,
#   'volume': 20999112,
#   'currency': '',
#   'change': 2.08,
#   'changePercent': 1.0759,
#   'label': 'Jul 26, 19',
#   'changeOverTime': 0.872738},
#  {'date': '2019-07-29',
#   'uClose': 199.9,
#   'uOpen': 204.85,
#   'uHigh': 203.14,
#   'uLow': 199.46,
#   'uVolume': 21177204,
#   'close': 195.57,
#   'open': 196.98,
#   'high': 197.11,
#   'low': 196.45,
#   'volume': 21020541,
#   'currency': '',
#   'change': -0.7,
#   'changePercent': -0.345,
#   'label': 'Jul 29, 19',
#   'changeOverTime': 0.84943},
#  {'date': '2019-07-30',
#   'uClose': 200.51,
#   'uOpen': 202.55,
#   'uHigh': 202.56,
#   'uLow': 193.22,
#   'uVolume': 19226035,
#   'close': 198.21,
#   'open': 200.81,
#   'high': 198.5,
#   'low': 195.88,
#   'volume': 18883992,
#   'currency': '',
#   'change': -0.85,
#   'changePercent': -0.4325,
#   'label': 'Jul 30, 19',
#   'changeOverTime': 0.848562},
#  {'date': '2019-07-31',
#   'uClose': 195.6,
#   'uOpen': 198.96,
#   'uHigh': 200.21,
#   'uLow': 197.16,
#   'uVolume': 42049942,
#   'close': 197,
#   'open': 202.95,
#   'high': 199.64,
#   'low': 193.11,
#   'volume': 42156670,
#   'currency': '',
#   'change': -2.7,
#   'changePercent': -1.414,
#   'label': 'Jul 31, 19',
#   'changeOverTime': 0.81316},
#  {'date': '2019-08-01',
#   'uClose': 193.68,
#   'uOpen': 191.99,
#   'uHigh': 200.71,
#   'uLow': 190.49,
#   'uVolume': 65551735,
#   'close': 199.6,
#   'open': 192.57,
#   'high': 202.29,
#   'low': 192.65,
#   'volume': 65963963,
#   'currency': '',
#   'change': -0.99,
#   'changePercent': -0.512,
#   'label': 'Aug 1, 19',
#   'changeOverTime': 0.830964},
#  {'date': '2019-08-02',
#   'uClose': 194.73,
#   'uOpen': 197.33,
#   'uHigh': 196.92,
#   'uLow': 194.66,
#   'uVolume': 56433945,
#   'close': 188.4,
#   'open': 195.55,
#   'high': 194.43,
#   'low': 189.43,
#   'volume': 57931922,
#   'currency': '',
#   'change': -2.9,
#   'changePercent': -1.4869,
#   'label': 'Aug 2, 19',
#   'changeOverTime': 0.811224},
#  {'date': '2019-08-05',
#   'uClose': 181.02,
#   'uOpen': 191.75,
#   'uHigh': 192.53,
#   'uLow': 186.1,
#   'uVolume': 78099397,
#   'close': 187.63,
#   'open': 187.09,
#   'high': 187.11,
#   'low': 187.5,
#   'volume': 78409865,
#   'currency': '',
#   'change': -6.82,
#   'changePercent': -3.5859,
#   'label': 'Aug 5, 19',
#   'changeOverTime': 0.71501},
#  {'date': '2019-08-06',
#   'uClose': 184.1,
#   'uOpen': 190.35,
#   'uHigh': 186.9,
#   'uLow': 185.6,
#   'uVolume': 42570081,
#   'close': 189.47,
#   'open': 190.11,
#   'high': 184.4,
#   'low': 189.28,
#   'volume': 43014076,
#   'currency': '',
#   'change': 2.61,
#   'changePercent': 1.4602,
#   'label': 'Aug 6, 19',
#   'changeOverTime': 0.75984},
#  {'date': '2019-08-07',
#   'uClose': 186.04,
#   'uOpen': 184.89,
#   'uHigh': 185.61,
#   'uLow': 181.74,
#   'uVolume': 50459913,
#   'close': 189.43,
#   'open': 184.79,
#   'high': 185.95,
#   'low': 186.84,
#   'volume': 51544157,
#   'currency': '',
#   'change': 1,
#   'changePercent': 0.5633,
#   'label': 'Aug 7, 19',
#   'changeOverTime': 0.748965},
#  {'date': '2019-08-08',
#   'uClose': 190.6,
#   'uOpen': 190.06,
#   'uHigh': 192.36,
#   'uLow': 193.14,
#   'uVolume': 38432865,
#   'close': 196.16,
#   'open': 185.34,
#   'high': 190.5,
#   'low': 193.16,
#   'volume': 39178807,
#   'currency': '',
#   'change': 4.18,
#   'changePercent': 2.1852,
#   'label': 'Aug 8, 19',
#   'changeOverTime': 0.79912},
#  {'date': '2019-08-09',
#   'uClose': 191.03,
#   'uOpen': 188.16,
#   'uHigh': 196,
#   'uLow': 186.27,
#   'uVolume': 34845917,
#   'close': 194.84,
#   'open': 193.28,
#   'high': 189,
#   'low': 191.53,
#   'volume': 34113297,
#   'currency': '',
#   'change': -1.78,
#   'changePercent': -0.978,
#   'label': 'Aug 9, 19',
#   'changeOverTime': 0.777706},
#  {'date': '2019-08-12',
#   'uClose': 191.43,
#   'uOpen': 186.87,
#   'uHigh': 190,
#   'uLow': 190.5,
#   'uVolume': 25403741,
#   'close': 191.02,
#   'open': 187.32,
#   'high': 187.6,
#   'low': 191.4,
#   'volume': 25709532,
#   'currency': '',
#   'change': -2.18,
#   'changePercent': -1.1655,
#   'label': 'Aug 12, 19',
#   'changeOverTime': 0.746319},
#  {'date': '2019-08-13',
#   'uClose': 190.26,
#   'uOpen': 192.64,
#   'uHigh': 196.04,
#   'uLow': 189.19,
#   'uVolume': 40741866,
#   'close': 197.31,
#   'open': 189.78,
#   'high': 198.9,
#   'low': 193.11,
#   'volume': 42369479,
#   'currency': '',
#   'change': 4.08,
#   'changePercent': 2.2385,
#   'label': 'Aug 13, 19',
#   'changeOverTime': 0.802914},
#  {'date': '2019-08-14',
#   'uClose': 187.38,
#   'uOpen': 191.81,
#   'uHigh': 191.48,
#   'uLow': 184.04,
#   'uVolume': 52728466,
#   'close': 183.68,
#   'open': 192.47,
#   'high': 186.68,
#   'low': 188.11,
#   'volume': 51331579,
#   'currency': '',
#   'change': -5.9,
#   'changePercent': -3.066,
#   'label': 'Aug 14, 19',
#   'changeOverTime': 0.736476},
#  {'date': '2019-08-15',
#   'uClose': 184.8,
#   'uOpen': 191.76,
#   'uHigh': 186.53,
#   'uLow': 189.71,
#   'uVolume': 38384271,
#   'close': 184.45,
#   'open': 192.23,
#   'high': 187.98,
#   'low': 181.77,
#   'volume': 37158273,
#   'currency': '',
#   'change': -0.22,
#   'changePercent': -0.1179,
#   'label': 'Aug 15, 19',
#   'changeOverTime': 0.728445},
#  {'date': '2019-08-16',
#   'uClose': 185.63,
#   'uOpen': 190.45,
#   'uHigh': 193.46,
#   'uLow': 190.9,
#   'uVolume': 35923788,
#   'close': 191.56,
#   'open': 192.73,
#   'high': 190.23,
#   'low': 191.8,
#   'volume': 35653554,
#   'currency': '',
#   'change': 2.97,
#   'changePercent': 1.68,
#   'label': 'Aug 16, 19',
#   'changeOverTime': 0.775837},
#  ...]
