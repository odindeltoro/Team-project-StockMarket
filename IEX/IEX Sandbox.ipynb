# %%
import os
import requests
import json
import pandas as pd
from splinter import Browser

# %%
UrlQQQ= "https://sandbox.iexapis.com/stable/stock/QQQ/chart/5y?token=Tsk_7632d79c09c34b78a432f5c1a6548cbb"

# %%
requests.get(UrlQQQ).json()
# Out:
# [{'date': '2015-08-26',
#   'uClose': 104.28,
#   'uOpen': 101.64,
#   'uHigh': 105.06,
#   'uLow': 101.14,
#   'uVolume': 106031415,
#   'close': 107.83,
#   'open': 104.34,
#   'high': 103.66,
#   'low': 99.73,
#   'volume': 104551230,
#   'currency': '',
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Aug 26, 15',
#   'changeOverTime': 0},
#  {'date': '2015-08-27',
#   'uClose': 107.39,
#   'uOpen': 109.56,
#   'uHigh': 106.01,
#   'uLow': 106.51,
#   'uVolume': 72712154,
#   'close': 110.6,
#   'open': 105.84,
#   'high': 107.14,
#   'low': 106.29,
#   'volume': 72479212,
#   'currency': '',
#   'change': 2.71,
#   'changePercent': 2.6058,
#   'label': 'Aug 27, 15',
#   'changeOverTime': 0.025488},
#  {'date': '2015-08-28',
#   'uClose': 106.25,
#   'uOpen': 106.74,
#   'uHigh': 109,
#   'uLow': 109.5,
#   'uVolume': 51148557,
#   'close': 109.33,
#   'open': 110.07,
#   'high': 109,
#   'low': 105.22,
#   'volume': 51911912,
#   'currency': '',
#   'change': -0.02,
# ...
